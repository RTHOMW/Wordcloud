# %%
#!/usr/bin/env python
"""
Masked wordcloud
================
Using a mask you can generate wordclouds in arbitrary shapes.
"""

from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'WordCloud/turtles announcements.txt'),errors="ignore").read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "WordCloud/kingblanc2.png")))

stopwords = set(STOPWORDS)
stopwords.update(["Â", "Å", "Ã", "â", "Ë","â","ÂÂ","IÃ","itÃ","Ëœâ","ÂÃ","ž","šÃ","š","https","tenor","advanced","advanced"])
#stopwords.add("Â")


wc = WordCloud(width=800, height=500,background_color="black", max_words=200, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='green',max_font_size=70)

#wc = WordCloud(width=1500, height=500,background_color="black", max_words=300,
#               stopwords=stopwords, contour_width=3, contour_color='steelblue',max_font_size=50)

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "WordCloud/king.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
